# %%
# !pip install groq
# !pip install top2vec[sentence_encoders]
# !pip install tika
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 44.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 77.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 4.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tika: filename=tika-2.6.0-py3-none-any.whl size=32623 sha256=7de10e4ac55508cb6f3d9e4dedcd3430df775f1811e51c2be1f14fdb8a753f9e
#   Stored in directory: /root/.cache/pip/wheels/5f/71/c7/b757709531121b1700cffda5b6b0d4aad095fb507ec84316d0
# Successfully built tika
# ...

# %%
# prompt: write code to read files from distrely using tika, store the parsed["content"] into a list of string

# !pip install tika

from tika import parser
import os

def read_files_from_directory(directory_path):
  """Reads files from a directory and returns a list of parsed content.

  Args:
    directory_path: The path to the directory containing the files.

  Returns:
    A list of strings, where each string is the parsed content of a file.
  """
  content_list = []
  for filename in os.listdir(directory_path):
    file_path = os.path.join(directory_path, filename)
    if os.path.isfile(file_path):
      try:
        parsed = parser.from_file(file_path)
        if parsed and "content" in parsed:
          content_list.append(parsed["content"])
      except Exception as e:
        print(f"Error parsing file {file_path}: {e}")

  return content_list

# Example usage:
directory_path = "/content/your_directory"  # Replace with your directory path
content_list = read_files_from_directory(directory_path)

# Print or process the content list
for content in content_list:
  print(content)

# %%
#!/usr/bin/env python
import tika
from tika import parser
parsed = parser.from_file('/content/#input text.pdf')
print(parsed["metadata"])
print(parsed["content"])
# Out:
# 2024-10-14 14:18:38,142 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server-standard/2.6.0/tika-server-standard-2.6.0.jar to /tmp/tika-server.jar.
# INFO:tika.tika:Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server-standard/2.6.0/tika-server-standard-2.6.0.jar to /tmp/tika-server.jar.
# 2024-10-14 14:18:38,718 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server-standard/2.6.0/tika-server-standard-2.6.0.jar.md5 to /tmp/tika-server.jar.md5.
# INFO:tika.tika:Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server-standard/2.6.0/tika-server-standard-2.6.0.jar.md5 to /tmp/tika-server.jar.md5.
# 2024-10-14 14:18:39,121 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...
# WARNING:tika.tika:Failed to see startup log message; retrying...
# ...

# %%
parsed = parser.from_file('/content/LlamaIndex (AI in Finance).pptx')
print(parsed["metadata"])
print(parsed["content"])
# Out:
# {'cp:revision': '1', 'extended-properties:AppVersion': '15.0000', 'dc:language': 'en-US', 'extended-properties:Application': 'LibreOffice/7.5.0.3$MacOSX_AARCH64 LibreOffice_project/c21113d003cd3efa8c53188764377a8272d9d6de', 'X-TIKA:Parsed-By-Full-Set': ['org.apache.tika.parser.DefaultParser', 'org.apache.tika.parser.microsoft.ooxml.OOXMLParser', 'org.apache.tika.parser.image.JpegParser', 'org.apache.tika.parser.image.ImageParser'], 'X-TIKA:content_handler': 'ToTextContentHandler', 'resourceName': ["b'LlamaIndex (AI in Finance).pptx'", 'image1.jpeg', 'image2.png', 'image11.png', 'image12.png', 'image13.png', 'image14.png', 'image15.png', 'image16.png', 'image17.png', 'image3.png', 'image4.png', 'image5.png', 'image6.png', 'image7.png', 'image8.png', 'image9.png', 'image10.png', 'image18.png', 'image19.png', 'image20.png', 'image21.png', 'image22.png', 'image23.png', 'image24.png', 'image25.png', 'image26.png'], 'dcterms:modified': '2024-10-08T08:05:04Z', 'extended-properties:Template'
# ...

# %%
parsed = parser.from_file('/content/Review Of Article.docx')
#print(parsed["metadata"])
print(parsed["content"])
# Out:
# {'cp:revision': '2', 'extended-properties:AppVersion': '14.0000', 'meta:paragraph-count': '196', 'meta:word-count': '14672', 'X-TIKA:Parsed-By-Full-Set': ['org.apache.tika.parser.DefaultParser', 'org.apache.tika.parser.microsoft.ooxml.OOXMLParser', 'org.apache.tika.parser.microsoft.EMFParser', 'org.apache.tika.parser.EmptyParser', 'org.apache.tika.parser.image.ImageParser', 'org.apache.tika.parser.image.JpegParser'], 'X-TIKA:content_handler': ['ToTextContentHandler', 'ToTextContentHandler', 'ToTextContentHandler', 'ToTextContentHandler', 'ToTextContentHandler', 'ToTextContentHandler', 'ToTextContentHandler', 'ToTextContentHandler', 'ToTextContentHandler', 'ToTextContentHandler', 'ToTextContentHandler', 'ToTextContentHandler', 'ToTextContentHandler', 'ToTextContentHandler', 'ToTextContentHandler', 'ToTextContentHandler', 'ToTextContentHandler', 'ToTextContentHandler', 'ToTextContentHandler', 'ToTextContentHandler', 'ToTextContentHandler', 'ToTextContentHandler', 'ToTextContentHandler'
# ...

# %%
from tika import parser
import os

def read_files_from_directory(directory_path):
  """Reads files from a directory and returns a list of parsed content.

  Args:
    directory_path: The path to the directory containing the files.

  Returns:
    A list of strings, where each string is the parsed content of a file.
  """
  content_list = []
  for filename in os.listdir(directory_path):
    file_path = os.path.join(directory_path, filename)
    if os.path.isfile(file_path):
      try:
        parsed = parser.from_file(file_path)
        if parsed and "content" in parsed:
          content_list.append(parsed["content"])
      except Exception as e:
        print(f"Error parsing file {file_path}: {e}")

  return content_list

# Example usage:
directory_path = "/content/"  # Replace with your directory path
content_list = read_files_from_directory(directory_path)

# Print or process the content list
for content in content_list:
  print(content)
# Out:
# ABSTRACT
# ...

# %%
content_list[2]
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nBuilding LLM Apps over Financial Data\nMuhammad Umair\n\n\n\n\nLlamaIndex: A data framework for LLM applications\nData Management and Query Engine for your LLM application\nOffers components across the data lifecycle: ingest, index, and query over data\nData Ingestion (LlamaHub 🦙)\nData Structures\nQueries\nConnect your existing data sources and data formats (API’s, PDF’s, docs, SQL, etc.)\nStore and index your data for different use cases. Integrate with different db’s (vector db, graph db, kv db)\nRetrieve and query over data\nIncludes: QA, Summarization, Agents, and more\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nRAG Stack\n\n\nCurrent RAG Stack for building a QA System\n\nVector Database\nDoc\nChunk\nChunk\nChunk\nChunk\nChunk\nChunk\nChunk\nLLM\nData Ingestion / Parsing\nData Querying\n5 Lines of Code in LlamaIndex!\n\n\n\nCurrent RAG Stack (Data Ingestion/Parsing)\n\nVector Database\nDoc\nChunk\nChunk\nChunk\nChunk\nProcess: \nSplit up doc
# ...

# %% [markdown]
# # Now builing Top2vec Embeddings

# %%
from top2vec import Top2Vec
from sklearn.datasets import fetch_20newsgroups

newsgroups = fetch_20newsgroups(subset='all', remove=('headers', 'footers', 'quotes'))

model = Top2Vec(documents=newsgroups.data, speed="fast-learn", workers=8)
# Out:
# 2024-10-14 14:33:12,342 - top2vec - INFO - Pre-processing documents for training
# INFO:top2vec:Pre-processing documents for training
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# 2024-10-14 14:33:12,414 - top2vec - INFO - Downloading universal-sentence-encoder-multilingual model
# INFO:top2vec:Downloading universal-sentence-encoder-multilingual model
# 2024-10-14 14:33:16,036 - top2vec - INFO - Creating joint document/word embedding
# INFO:top2vec:Creating joint document/word embedding
# 2024-10-14 14:33:23,131 - top2vec - INFO - Creating lower dimension embedding of documents
# INFO:top2vec:Creating lower dimension embedding of documents
# /usr/local/lib/python3.10/dist-packages/umap/umap_.py:2437: UserWarning: n_neighbors is larger than the dataset size; truncating to X.shape[0] - 1
#   warn(
# ...

# %%
documents, doc_scores, doc_id = model.query_documents("Dr. Tahir Ijaz comments on Esam Abdel-Rahem's statement:?", num_docs=3)
for i in documents:
  print(i)
  print("*************

# %%
from groq import Groq

client = Groq(api_key = key )
completion = client.chat.completions.create(
    model="llama3-8b-8192",
    messages=[
        {
            "role": "system",
            "content": "Your need to write Python code for said problems, just retune the code without any explanations"
        },
        {
            "role": "user",
            "content": "Write a fucntion that takes an input and print cubes and squars"
        }
    ],
    temperature=1,
    max_tokens=5000,
    top_p=1,
    stream=True,
    stop=None,
)

for chunk in completion:
    print(chunk.choices[0].delta.content or "", end="")
